# %% [markdown]
# # EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline 

# 한글 문제 해결
# matplotlib의 기본폰트에서 한글이 지원되지 않음
# 시스템별로 한글 지원하는 폰트로 변경해야 함

import platform
from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':  # 맥OS 
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':  # 윈도우
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)

# %% [markdown]
# ## 데이터 불러오기

# %%
data=pd.read_csv("data/final_data.csv")
data
# Out:
#                      시간대  성별  연령대   지역  기분 1순위 2순위 3순위    기온  강수량  ...  초밥  \
# 0    2021-05-16 14:00:00  남자   청년  수도권  행복  한식  일식  중식  17.5  1.6  ...   2
# 1    2021-05-16 15:00:00  여자  중장년   서울  분노  한식  중식  일식  18.5  1.4  ...   0
# 2    2021-05-16 15:00:00  남자   청년   서울  중립  일식  양식  한식  18.5  1.4  ...   0
# 3    2021-05-16 15:00:00  여자   청년   서울  행복  일식  한식  분식  18.5  1.4  ...   3
# 4    2021-05-16 16:00:00  남자   청년  경상도  행복  양식  일식  분식  20.6  2.6  ...   2
# ..                   ...  ..  ...  ...  ..  ..  ..  ..   ...  ...  ...  ..
# 416  2021-05-24 16:00:00  남자   노년  경상도  행복  한식  분식  중식  23.8  0.0  ...   0
# 417  2021-05-24 16:00:00  남자   노년  수도권  행복  한식  일식  중식  22.1  0.0  ...   0
# 418  2021-05-24 16:00:00  여자   노년  전라도  행복  한식  중식  일식  22.7  0.0  ...   0
# 419  2021-05-24 16:00:00  남자   노년  전라도  우울  분식  양식  일식  22.7  0.0  ...   0
# 420  2021-05-24 16:00:00  여자   노년  전라도  행복  한식  중식  일식  22.7  0.0  ...   0
#
#      우동  메밀소바  돈가스  볶음밥  짜장면  짬뽕     날짜  시간  요일
# ...

# %%
mk=data[["성별","연령대","기분","1순위","2순위","3순위"]]
mk
# Out:
#      성별  연령대  기분 1순위 2순위 3순위
# 0    남자   청년  행복  한식  일식  중식
# 1    여자  중장년  분노  한식  중식  일식
# 2    남자   청년  중립  일식  양식  한식
# 3    여자   청년  행복  일식  한식  분식
# 4    남자   청년  행복  양식  일식  분식
# ..   ..  ...  ..  ..  ..  ..
# 416  남자   노년  행복  한식  분식  중식
# 417  남자   노년  행복  한식  일식  중식
# 418  여자   노년  행복  한식  중식  일식
# 419  남자   노년  우울  분식  양식  일식
# 420  여자   노년  행복  한식  중식  일식
#
# [421 rows x 6 columns]

# %% [markdown]
# ## 설문데이터 시각화

# %%
# pie그래프 함수
def pieplot(column): 
    tmp=mk[column].value_counts()
    colors = ['#ff9999', '#8fd9b6', '#ffc000', '#d395d0','#ffcc99']
    wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}
    plt.pie(tmp.values, labels=tmp.index, autopct='%.1f%%', startangle=260, counterclock=False, colors=colors, wedgeprops=wedgeprops)

# %%
pieplot(column="1순위")

# %%
data2=pd.read_csv("data/final_data.csv")
data2
# Out:
#                      시간대  성별  연령대   지역  기분 1순위 2순위 3순위    기온  강수량  ...  초밥  \
# 0    2021-05-16 14:00:00  남자   청년  수도권  행복  한식  일식  중식  17.5  1.6  ...   2
# 1    2021-05-16 15:00:00  여자  중장년   서울  분노  한식  중식  일식  18.5  1.4  ...   0
# 2    2021-05-16 15:00:00  남자   청년   서울  중립  일식  양식  한식  18.5  1.4  ...   0
# 3    2021-05-16 15:00:00  여자   청년   서울  행복  일식  한식  분식  18.5  1.4  ...   3
# 4    2021-05-16 16:00:00  남자   청년  경상도  행복  양식  일식  분식  20.6  2.6  ...   2
# ..                   ...  ..  ...  ...  ..  ..  ..  ..   ...  ...  ...  ..
# 416  2021-05-24 16:00:00  남자   노년  경상도  행복  한식  분식  중식  23.8  0.0  ...   0
# 417  2021-05-24 16:00:00  남자   노년  수도권  행복  한식  일식  중식  22.1  0.0  ...   0
# 418  2021-05-24 16:00:00  여자   노년  전라도  행복  한식  중식  일식  22.7  0.0  ...   0
# 419  2021-05-24 16:00:00  남자   노년  전라도  우울  분식  양식  일식  22.7  0.0  ...   0
# 420  2021-05-24 16:00:00  여자   노년  전라도  행복  한식  중식  일식  22.7  0.0  ...   0
#
#      우동  메밀소바  돈가스  볶음밥  짜장면  짬뽕     날짜  시간  요일
# ...

# %%
for i in range(len(data2)):
    if data2.loc[i,'강수량']==0:
        data2.loc[i,"비"]="비안옴"
    else :
        data2.loc[i,"비"]="비옴"

# %%
data2
# Out:
#                      시간대  성별  연령대   지역  기분 1순위 2순위 3순위    기온  강수량  ...  우동  \
# 0    2021-05-16 14:00:00  남자   청년  수도권  행복  한식  일식  중식  17.5  1.6  ...   0
# 1    2021-05-16 15:00:00  여자  중장년   서울  분노  한식  중식  일식  18.5  1.4  ...   0
# 2    2021-05-16 15:00:00  남자   청년   서울  중립  일식  양식  한식  18.5  1.4  ...   0
# 3    2021-05-16 15:00:00  여자   청년   서울  행복  일식  한식  분식  18.5  1.4  ...   0
# 4    2021-05-16 16:00:00  남자   청년  경상도  행복  양식  일식  분식  20.6  2.6  ...   0
# ..                   ...  ..  ...  ...  ..  ..  ..  ..   ...  ...  ...  ..
# 416  2021-05-24 16:00:00  남자   노년  경상도  행복  한식  분식  중식  23.8  0.0  ...   0
# 417  2021-05-24 16:00:00  남자   노년  수도권  행복  한식  일식  중식  22.1  0.0  ...   0
# 418  2021-05-24 16:00:00  여자   노년  전라도  행복  한식  중식  일식  22.7  0.0  ...   0
# 419  2021-05-24 16:00:00  남자   노년  전라도  우울  분식  양식  일식  22.7  0.0  ...   0
# 420  2021-05-24 16:00:00  여자   노년  전라도  행복  한식  중식  일식  22.7  0.0  ...   0
#
#      메밀소바  돈가스  볶음밥  짜장면  짬뽕     날짜  시간  요일    비
# ...

# %%
for i in range(len(data2)):
    if 0<= data2.loc[i,"전운량"] <=5:
        data2.loc[i,"구름"]="맑음"
    elif 6<= data2.loc[i,"전운량"] <=8:
         data2.loc[i,"구름"]="구름많음"
    else:
        data2.loc[i,"구름"]="흐림"

# %%
mk=data2[["구름","비"]]
mk
# Out:
#      구름    비
# 0    흐림   비옴
# 1    흐림   비옴
# 2    흐림   비옴
# 3    흐림   비옴
# 4    흐림   비옴
# ..   ..  ...
# 416  맑음  비안옴
# 417  맑음  비안옴
# 418  맑음  비안옴
# 419  맑음  비안옴
# 420  맑음  비안옴
#
# [421 rows x 2 columns]

# %%
pieplot("구름")

# %%
pieplot("비")

# %%
mk=data2[["요일","시간"]]
mk
# Out:
#     요일  시간
# 0    일  14
# 1    일  15
# 2    일  15
# 3    일  15
# 4    일  16
# ..  ..  ..
# 416  월  16
# 417  월  16
# 418  월  16
# 419  월  16
# 420  월  16
#
# [421 rows x 2 columns]

# %%
for i in range(len(data2)):
    if data2.loc[i, "시간"]>=16 and data2.loc[i, "시간"]<=23:
        data2.loc[i, "식사시간"] = "저녁"
    elif data2.loc[i, "시간"]>=11 and data2.loc[i, "시간"]<16:
        data2.loc[i, "식사시간"] = '점심'
    else:
        data2.loc[i, "식사시간"] = "아침"

# %%
for i in range(len(data2)):
    if data2.loc[i, "요일"] == "일":
        data2.loc[i, "휴일"] = "주말"
    else:
        data2.loc[i, "휴일"] = "평일"

# %%
mk=data2[["식사시간","휴일"]]

# %%
pieplot("식사시간")

# %%
pieplot("휴일")

# %%
ax=sns.countplot(x="1순위", data=data2,hue="식사시간")

# %%
ax=sns.countplot(x="1순위", data=data2,hue="식사시간")

# %%
ax=sns.countplot(x="연령대", data=data2,hue="2순위")

# %%
ax=sns.countplot(x="연령대", data=data2,hue="3순위")
